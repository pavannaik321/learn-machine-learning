# %% [markdown]
# <a href="https://colab.research.google.com/github/pavannaik321/learn-machine-learning/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##question 7
# write a pandas program

# %%
import pandas as pd
import requests
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv"
# data = requests.get("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv").content
# df = pd.read_csv(data)
df = pd.read_csv(url)
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ##i. To read a csv file from a specified source and print the first 7 rows

# %%
df.iloc[0:7,:]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %% [markdown]
# ##Question 1
# write a pandas program to convert your name as dictionary into a pandas series

# %%
names = {"1" : "pavan","2":"aditya"}
series = pd.Series(names)
series
# Out:
# 1     pavan
# 2    aditya
# dtype: object

# %% [markdown]
# ##Question 2
# write a pandas program to convert a NumPy array to Pandas series

# %%
import numpy as np

# %%
array = np.array([1,2,3,4])
question2_series = pd.Series(array)
question2_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ##Question 3
# write a pandas program to create the mean and standard deviation of the data of a given series

# %%
data = pd.Series(data = [1,2,3,4,5,6,7,8,9])
data
mean = data.mean()
standard_deviation = data.std()
print(mean)
print(standard_deviation)
# Out:
# 5.0
# 2.7386127875258306
